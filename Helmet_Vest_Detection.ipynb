# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/safety/blob/master/Helmet_Vest_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.35 MiB | 21.39 MiB/s, done.
# Resolving deltas: 100% (10670/10670), done.

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	Dockerfile.cpu	       LICENSE	      scripts
# build		darknet_images.py	Dockerfile.gpu	       Makefile       src
# build.ps1	darknet.py		image_yolov3.sh        net_cam_v3.sh  vcpkg.json
# cfg		darknet_video.py	image_yolov4.sh        net_cam_v4.sh  vcpkg.json.opencv23
# cmake		data			include		       package.xml    video_yolov3.sh
# CMakeLists.txt	docker-compose.yml	json_mjpeg_streams.sh  README.md      video_yolov4.sh

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ...

# %%
# !ls
# Out:
# 3rdparty	darknet			Dockerfile.cpu	       Makefile       scripts
# backup		DarknetConfig.cmake.in	Dockerfile.gpu	       net_cam_v3.sh  src
# build		darknet_images.py	image_yolov3.sh        net_cam_v4.sh  vcpkg.json
# build.ps1	darknet.py		image_yolov4.sh        obj	      vcpkg.json.opencv23
# cfg		darknet_video.py	include		       package.xml    video_yolov3.sh
# cmake		data			json_mjpeg_streams.sh  README.md      video_yolov4.sh
# CMakeLists.txt	docker-compose.yml	LICENSE		       results

# %%
! ./darknet
# Out:
# usage: ./darknet <function>

# %%
# !wget https://pjreddie.com/media/files/darknet19_448.conv.23
# Out:
# --2024-04-07 06:24:56--  https://pjreddie.com/media/files/darknet19_448.conv.23
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79327120 (76M) [application/octet-stream]
# Saving to: ‘darknet19_448.conv.23’
#
# darknet19_448.conv. 100%[===================>]  75.65M  27.5MB/s    in 2.8s
#
# 2024-04-07 06:25:03 (27.5 MB/s) - ‘darknet19_448.conv.23’ saved [79327120/79327120]

# %%
# !git clone https://github.com/mohanrajmit/safety.git
# Out:
# Cloning into 'safety'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 313 (delta 4), reused 0 (delta 0), pack-reused 301
# Receiving objects: 100% (313/313), 239.12 MiB | 47.66 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !cp /content/darknet/safety/train.txt /content/darknet

# %%
# !cp /content/darknet/safety/test.txt /content/darknet

# %%
# !cp /content/darknet/safety/yolo-voc.2.0.cfg /content/darknet/cfg

# %%
# !cp /content/darknet/safety/obj.data /content/darknet/cfg

# %%
# !cp /content/darknet/safety/obj.names /content/darknet/cfg

# %%
mv /content/darknet/safety/dataset /content/darknet

# %%
# !./darknet detector train cfg/obj.data cfg/yolo-voc.2.0.cfg darknet19_448.conv.23 -dont_show 0
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV isn't used - data augmentation will be slow
# yolo-voc
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 8, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max                2x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max                2x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: copy files to one path to other paths

# !cp /content/darknet/backup/yolo-voc_last.weights /content/drive/MyDrive/yolo_weights
